# %%
from dbfread import DBF
import pandas as pd

# %%
dbf = DBF(r'C:\Users\taohuang\Downloads\uavgcp2.dbf')
dbf
# Out:
# <unloaded DBF table 'C:\\Users\\taohuang\\Downloads\\uavgcp2.dbf'>

# %%
frame = pd.DataFrame(iter(dbf))
frame
# Out:
#    OBJNAME        lat         lon          ele              x             y  \
# 0      100  43.126072 -116.753781  1648.761454  520027.813239  4.774844e+06
# 1      101  43.125312 -116.753858  1650.799164  520021.796079  4.774760e+06
# 2      103  43.125003 -116.753832  1652.655994  520024.063315  4.774726e+06
# 3      104  43.124862 -116.753561  1655.960181  520046.143612  4.774710e+06
# 4      105  43.125067 -116.753444  1656.049297  520055.533874  4.774733e+06
# 5      106  43.124708 -116.754546  1646.540785  519966.066523  4.774693e+06
# 6      107  43.124951 -116.754620  1645.627267  519959.959181  4.774720e+06
# 7      108  43.125204 -116.754399  1645.994283  519977.872625  4.774748e+06
# 8      110  43.125309 -116.754132  1648.217930  519999.552847  4.774760e+06
# 9      111  43.126643 -116.754662  1646.184558  519956.002971  4.774908e+06
# 10     112  43.126913 -116.754555  1646.216314  519964.595395  4.774938e+06
# ...

# %%
frame["ele"].mean()
# Out:
# 1647.425878777778

# %%
frame.to_csv(r'C:\Users\taohuang\Downloads\uavgcp2.csv')
